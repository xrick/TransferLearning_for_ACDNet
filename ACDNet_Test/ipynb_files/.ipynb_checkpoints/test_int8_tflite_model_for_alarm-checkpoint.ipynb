# %% [markdown]
# ## 測試項目
# 1. 訓練集中的alarm聲
# 2. 使用pruned and quantized tflite model
# 4. export to cc file

# %%
import os
import sys
import datetime
import shutil
import numpy as np
import tensorflow as tf
# from tensorflow import keras
import zipfile
import wavio
from common import utils as U
np.set_printoptions(threshold=sys.maxsize)

# %%
sys.path.append(os.path.abspath("../../deployment/"))
sys.path.append(os.path.abspath("../../common/"))
sys.path.append(os.path.abspath("../../"))

# %%
from lib_original.bytes import to_bytes, from_bytes, byte_conversion_tests, load_data, load_raw, save_raw, save_scores
from lib_original.constants import quant_support, crops, feature_count
from lib_original.quantize import quantization_tests, get_cast

# %%
from datetime import datetime
import re

# %%
def get_cast_input_data(x, dtype = None):
    '''Retrieves the input data set, casting to target dtype'''
    x, y = self.get_input_data()

    if dtype is None:
      print('dtype not provided')
      return x  
    return get_cast(dtype)(x, axis = -2)

# %% [markdown]
# ### Loading TFlite Model

# %%
tflite_quant_model_path = "./models/tflite/retrain_pruned_model_20240130161638_from_keras.tflite";
# Load quantized TFLite model
tflite_interpreter_quant = tf.lite.Interpreter(model_path=tflite_quant_model_path)

# %%
# model.summary()
input_details = tflite_interpreter_quant.get_input_details()
output_details = tflite_interpreter_quant.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

#resize the input and output
# tflite_interpreter_quant.resize_tensor_input(input_details[0]['index'], (2, 1, 30225, 1))
# tflite_interpreter_quant.resize_tensor_input(output_details[0]['index'], (2, 2))

# input_details = tflite_interpreter_quant.get_input_details()
# output_details = tflite_interpreter_quant.get_output_details()

# print("== Input details ==")
# print("name:", input_details[0]['name'])
# print("shape:", input_details[0]['shape'])
# print("type:", input_details[0]['dtype'])

# print("\n== Output details ==")
# print("name:", output_details[0]['name'])
# print("shape:", output_details[0]['shape'])
# print("type:", output_details[0]['dtype'])

tflite_interpreter_quant.allocate_tensors();
# Out:
# == Input details ==
# name: serving_default_input_2:0
# shape: [    1     1 30225     1]
# type: <class 'numpy.int8'>
#
# == Output details ==
# name: StatefulPartitionedCall:0
# shape: [1 2]
# type: <class 'numpy.int8'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### loading dataset from npz format
# 1. ACDNet input length is 30225
# 2. sr is 44100 and 20000
# 3. need to convert 16K to 20000
# ### ACDNet Config Setting
# #### Training Parameters
# 1. opt.batchSize = 64;
# 2. opt.weightDecay = 5e-4;
# 3. opt.momentum = 0.9;
# 4. opt.nEpochs = 2000;
# 5. opt.LR = 0.1;
# 6. opt.schedule = [0.3, 0.6, 0.9];
# 7. opt.warmup = 10;
# #### Basic Net Configuration
# - nClasses = 50
# - nFolds = 5
# - splits = \[i for in range(1, nFolds + 1)\]
# - sr = 20000
# - inputLength = 30225
# <br>ngth = 30225;
# ### How to convert 16K sound to 44.1K with python and sox
#
# if using sox the command is as following: <br />
#     sox old.wav -b 16 new.wav
# if using python you can do as following: <br />
#     import soundfile
#
# data, samplerate = soundfile.read('old.wav
#     <br />)
# soundfile.write('new.wav', data, samplerate, subtype='PCM_1
# 6')

# %%
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def getFileList(srcDir,regex='.*\.wav'):
    results = os.listdir(srcDir)
    out_files = []
    cnt_files = 0
    for file in results:
        if os.path.isdir(os.path.join(srcDir, file)):
            out_files += getFileList(os.path.join(srcDir, file))
        elif re.match(regex, file,  re.I):  # file.startswith(startExtension) or file.endswith(".txt") or file.endswith(endExtension):
            out_files.append(os.path.join(srcDir, file))
            cnt_files = cnt_files + 1
    return out_files

# %% [markdown]
# ## sound preprocessing functions

# %%
_inputLen = 30225
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess_debug():
    debug_funcs = []
    debug_funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),]
              # U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return debug_funcs

def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)

    return sound;

# %%
_funcs = preprocess_setup()
# _debug_funcs = preprocess_debug()

# %% [markdown]
# ### Read Test Wav File

# %%
#specify the input type:
dtype = 'int8'

positive_test_wavs = "./test_sounds/positive/"
negative_test_wavs_others = "./test_sounds/negative/othersounds/"
negative_test_wavs_siren = "./test_sounds/negative/siren/"

p_wav_list = getFileList(positive_test_wavs);
n_wav_list_other = getFileList(negative_test_wavs_others);
n_wav_list_siren = getFileList(negative_test_wavs_siren);
print(f"total alarm sounds:{len(p_wav_list)} ");
print(f"total other sounds:{len(n_wav_list_other)}")
print(f"total siren sounds:{len(n_wav_list_siren)}")
p_label = 52;
n_label = 99;

sounds_1 = [];
labels_1 = [];
sounds_2 = [];
labels_2 = [];
## sound = preprocess(sound, _funcs)
for i in p_wav_list:
    sound = wavio.read(i).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1]
    label = int(p_label);
    if len(sound)> 220500:
        sound = sound[:220500]
    sound = preprocess(sound, _funcs);
    sounds_1.append(sound);
    labels_1.append(label);
    sounds_2.append(sound);
    labels_2.append(label);
    
for j in n_wav_list_other:
    sound = wavio.read(j).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1];
    label = int(n_label);
    sound = np.float32(preprocess(sound, _funcs));
    sounds_1.append(sound);
    labels_1.append(label);

for k in n_wav_list_siren:
    sound = wavio.read(j).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1];
    label = int(n_label);
    sound = np.float32(preprocess(sound, _funcs));
    sounds_1.append(sound);
    labels_1.append(label);
    sounds_2.append(sound);
    labels_2.append(label);

print(f"sound testset 1 length: {len(sounds_1)}");
print(f"sound testset 2 length: {len(sounds_2)}");

# sound = wavio.read(test_sound_file).data.T[0]
# start = sound.nonzero()[0].min()
# end = sound.nonzero()[0].max()
# sound = sound[start: end + 1]  # Remove silent sections
# label = 18 #int(os.path.splitext(test_sound_file)[0].split('-')[-1])

# if len(sound)> 220500:
#     sound = sound[:220500]

# ec50_sound1 =  wavio.read(ec50_18_sound).data.T[0]
# start_ec50 = ec50_sound1.nonzero()[0].min()
# end_ec50 = ec50_sound1.nonzero()[0].max()
# ec50_sound1 = ec50_sound1[start_ec50:end_ec50+1]
# ec50_18_label = 18
# Out:
# total alarm sounds:116
# total other sounds:128
# total siren sounds:91
# sound testset 1 length: 335
# sound testset 2 length: 207

# %%
# print(sounds)
# print(labels)

# %%
print(sounds_1[0][1].shape)
print(type(labels_1[0]))
# Out:
# (30225,)
# <class 'int'>

# %%
# sound = np.expand_dims(sound, axis=1)
# sound = np.expand_dims(sound, axis=3)
# print(sound.shape)

# %%
test1_len = len(sounds_1);
test2_len = len(sounds_2)
len_alarm = len(p_wav_list);
len_siren = len(n_wav_list_siren);
len_other = len(n_wav_list_other);
n_total_len = len_other + len_siren ;
# s_total_len = len(n_wav_list_siren);
print(f"total alarm sounds is {len_alarm}\ntotal other sounds is {n_total_len}(other:{len_other} + siren:{len_siren})");
test1_correct_num = 0;
test2_correct_num = 0;
test1_p_correct_num = 0;
test2_p_correct_num = 0;
n_correct_num = 0;
n_correct_siren_num = 0;
n_correct_othersounds_num = 0;

for w in range(test1_len): 
    s = sounds_1[w]
    l = labels_1[w]
    s_test = np.expand_dims(s[0], axis=0);
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    #get_cast(dtype)(sound, axis = -2)
    # s_test = np.int8(s_test);
    s_test = get_cast(dtype)(s_test, axis=-2)
    print(s_test.shape)
    tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter_quant.invoke()
    pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
    # print(f"Prediction result shape:{pred.shape}\n");
    print(f"Prediction result: {pred}, and true label: {l}")
    if l == 52: #positive
        if pred[0][0] > pred[0][1]:
            test1_correct_num += 1;
            test1_p_correct_num += 1;
    if l == 99: #negative
        if pred[0][0] < pred[0][1]:
            test1_correct_num += 1;
            n_correct_num += 1;
            
for w in range(test2_len): 
    s = sounds_2[w]
    l = labels_2[w]
    s_test = np.expand_dims(s[0], axis=0);
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    # s_test = np.float32(s_test);
    s_test = get_cast(dtype)(s_test, axis=-2)
    # print(s_test.shape)
    # print(f"the {w+1} item's shape:\n  {s.shape}");
    # Run inference
    # print(f"s type:{type(s)}, and s shape:{s.shape}")
    tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter_quant.invoke()
    pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
    # print(f"Prediction result shape:{pred.shape}\n");
    print(f"Prediction result: {pred}, and true label: {l}")
    if l == 52: #positive
        if pred[0][0] > pred[0][1]:
            test2_correct_num += 1;
            test2_p_correct_num += 1;
    if l == 99: #negative
        if pred[0][0] < pred[0][1]:
            test2_correct_num += 1;
            n_correct_siren_num += 1;
print(f"test1: total sounds(alarm+other+siren)test result is {100*(test1_correct_num/test1_len)}");
print(f"test1: total alarm sounds result is {100*(test1_p_correct_num/len_alarm)}");
print(f"test1 total other sounds(other+siren) result is {100*n_correct_num/n_total_len}");
print("**************************************************************************************")
print(f"test2: total sounds(alarm+siren)test result is {100*(test2_correct_num/test2_len)}")
print(f"test1: total alarm sounds result is {100*(test2_p_correct_num/len_alarm)}");
print(f"test2 total siren sounds result is {100*n_correct_siren_num/len_siren}");
# Out:
# total alarm sounds is 116
# total other sounds is 219(other:128 + siren:91)
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-86  86]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-73  73]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-117  117]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-111  111]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-51  51]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-115  115]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-37  37]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-75  75]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-50  50]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-69  69]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-79  79]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-69  69]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-123  123]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-98  98]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-120  120]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-105  105]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-124  124]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-111  111]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-72  72]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-108  108]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-77  77]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-110  110]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-93  93]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-119  119]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-80  80]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-112  112]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-98  98]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-67  67]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-70  70]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-95  95]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-93  93]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-89  89]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-120  120]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-49  49]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-77  77]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-56  56]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-53  53]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-106  106]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-50  50]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-118  118]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-72  72]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-115  115]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-118  118]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-73  73]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-90  90]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-102  102]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-41  41]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-114  114]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-88  88]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-29  29]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-15  15]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-53  53]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-106  106]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-106  106]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-50  50]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-56  56]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-82  82]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-59  59]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-102  102]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-90  90]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-91  91]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-25  25]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-76  76]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-86  86]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-83  83]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-91  91]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-67  67]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-93  93]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-80  80]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-32  32]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-34  34]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-85  85]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-92  92]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-106  106]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-15  15]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-101  101]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-51  51]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-93  93]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-63  63]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-70  70]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-29  29]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-95  95]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-113  113]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-90  90]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-15  15]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-59  59]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-13  13]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-85  85]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-114  114]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-20  20]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-37  37]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-46  46]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-119  119]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-105  105]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-105  105]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-115  115]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-83  83]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-116  116]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-86  86]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-81  81]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-75  75]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-79  79]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-89  89]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-64  64]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-69  69]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-74  74]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-36  36]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-102  102]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-123  123]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-89  89]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-65  65]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-100  100]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-60  60]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-18  18]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-105  105]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-82  82]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-83  83]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-121  121]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-95  95]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-46  46]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-64  64]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-18  18]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-46  46]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-16  16]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-105  105]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-69  69]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-81  81]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-22  22]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-107  107]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-10  10]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-56  56]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-79  79]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-102  102]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-82  82]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-60  60]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-103  103]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-62  62]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-87  87]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-97  97]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-102  102]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-96  96]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-111  111]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-84  84]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-82  82]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# (1, 1, 30225, 1)
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-86  86]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-73  73]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-117  117]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-111  111]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-100  100]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-51  51]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-115  115]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-37  37]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-75  75]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-74  74]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-104  104]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-50  50]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-103  103]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-69  69]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-100  100]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-79  79]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-121  121]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-69  69]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-123  123]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-103  103]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-98  98]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-120  120]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-62  62]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-87  87]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-105  105]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-124  124]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-111  111]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-72  72]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-108  108]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-107  107]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-77  77]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-110  110]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-93  93]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-119  119]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-80  80]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-112  112]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-98  98]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-67  67]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-88  88]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-70  70]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-95  95]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-101  101]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-93  93]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-89  89]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-120  120]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-49  49]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-96  96]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-113  113]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-77  77]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-56  56]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-60  60]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-114  114]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-53  53]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-62  62]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-106  106]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-74  74]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-50  50]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-84  84]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-116  116]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-118  118]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-72  72]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-91  91]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-76  76]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-115  115]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-97  97]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-94  94]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-109  109]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-59  59]], and true label: 52
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# Casting dataset to int8
# Prediction result: [[-99  99]], and true label: 99
# test1: total sounds(alarm+other+siren)test result is 65.3731343283582
# test1: total alarm sounds result is 0.0
# test1 total other sounds(other+siren) result is 100.0
# **************************************************************************************
# test2: total sounds(alarm+siren)test result is 43.96135265700483
# test1: total alarm sounds result is 0.0
# test2 total siren sounds result is 100.0

# %%
# scores = model.predict(sound, batch_size=len(sound), verbose=0);
# print(type(scores))
# print(scores.shape)

# for res in scores:
#     max_value = res.max()的
#     max_index = np.argmax(res)
#     print(f"max value:{max_value:.5f} and index is {max_index}")
#     print('\n'.join('{}: {:.5f}'.format(*k) for k in enumerate(res)))
