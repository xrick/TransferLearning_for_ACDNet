# %% [markdown]
# ## 測試項目
# 1. 訓練集中的alarm聲
# 2. 使用pruned and quantized tflite model
# 4. export to cc file

# %%
import os
import sys
import datetime
import shutil
import numpy as np
import tensorflow as tf
# from tensorflow import keras
import zipfile
import wavio
from common import utils as U
# Out:
# 2024-01-12 10:39:28.051036: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-12 10:39:28.070908: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-12 10:39:28.070927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-12 10:39:28.071440: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-12 10:39:28.074795: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-12 10:39:28.426979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from datetime import datetime
import re

# %% [markdown]
# ### Loading TFlite Model

# %%
tflite_quant_model_path = "./models/tflite/acdnet_model_acc96_55_prunned20240110135513.tflite";
# Load quantized TFLite model
tflite_interpreter_quant = tf.lite.Interpreter(model_path=tflite_quant_model_path)

# %%
# model.summary()
input_details = tflite_interpreter_quant.get_input_details()
output_details = tflite_interpreter_quant.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

#resize the input and output
# tflite_interpreter_quant.resize_tensor_input(input_details[0]['index'], (2, 1, 30225, 1))
# tflite_interpreter_quant.resize_tensor_input(output_details[0]['index'], (2, 2))

# input_details = tflite_interpreter_quant.get_input_details()
# output_details = tflite_interpreter_quant.get_output_details()

# print("== Input details ==")
# print("name:", input_details[0]['name'])
# print("shape:", input_details[0]['shape'])
# print("type:", input_details[0]['dtype'])

# print("\n== Output details ==")
# print("name:", output_details[0]['name'])
# print("shape:", output_details[0]['shape'])
# print("type:", output_details[0]['dtype'])

tflite_interpreter_quant.allocate_tensors();
# Out:
# == Input details ==
# name: x.3
# shape: [    1     1 30225     1]
# type: <class 'numpy.float32'>
#
# == Output details ==
# name: 185
# shape: [1 2]
# type: <class 'numpy.float32'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### loading dataset from npz format
# 1. ACDNet input length is 30225
# 2. sr is 44100 and 20000
# 3. need to convert 16K to 20000
# ### ACDNet Config Setting
# #### Training Parameters
# 1. opt.batchSize = 64;
# 2. opt.weightDecay = 5e-4;
# 3. opt.momentum = 0.9;
# 4. opt.nEpochs = 2000;
# 5. opt.LR = 0.1;
# 6. opt.schedule = [0.3, 0.6, 0.9];
# 7. opt.warmup = 10;
# #### Basic Net Configuration
# - nClasses = 50
# - nFolds = 5
# - splits = \[i for in range(1, nFolds + 1)\]
# - sr = 20000
# - inputLength = 30225
# <br>ngth = 30225;
# ### How to convert 16K sound to 44.1K with python and sox
#
# if using sox the command is as following: <br />
#     sox old.wav -b 16 new.wav
# if using python you can do as following: <br />
#     import soundfile
#
# data, samplerate = soundfile.read('old.wav
#     <br />)
# soundfile.write('new.wav', data, samplerate, subtype='PCM_1
# 6')

# %%
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def getFileList(srcDir,regex='.*\.wav'):
    results = os.listdir(srcDir)
    out_files = []
    cnt_files = 0
    for file in results:
        if os.path.isdir(os.path.join(srcDir, file)):
            out_files += getMp3List(os.path.join(srcDir, file))
        elif re.match(regex, file,  re.I):  # file.startswith(startExtension) or file.endswith(".txt") or file.endswith(endExtension):
            out_files.append(os.path.join(srcDir, file))
            cnt_files = cnt_files + 1
    return out_files

# %% [markdown]
# ## sound preprocessing functions

# %%
_inputLen = 30225
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)

    return sound;

# %%
_funcs = preprocess_setup()

# %% [markdown]
# ### Read Test Wav File

# %%
positive_test_wavs = "../../../ACDNet_Test/sounds_for_test/positive/"
negative_test_wavs = "../../../ACDNet_Test/sounds_for_test/negative/siren/"

p_wav_list = getFileList(positive_test_wavs);
n_wav_list = getFileList(negative_test_wavs);

print(f"total alarm sounds:{len(p_wav_list)} ");
print(f"total other sounds:{len(n_wav_list)}")
p_label = 52;
n_label = 99;

sounds = [];
labels = [];
## sound = preprocess(sound, _funcs)
for i in p_wav_list:
    sound = wavio.read(i).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1]
    print(f"sound content before preprocess:\n{sound}")
    label = int(p_label);
    print(f"current sound start:{start} to end:{end}");
    print(f"label is {label} and sound len is {len(sound)}");
    label = int(p_label);
    if len(sound)> 220500:
        sound = sound[:220500]
    sound = preprocess(sound, _funcs);
    sounds.append(sound);
    labels.append(label);
    
for j in n_wav_list:
    sound = wavio.read(j).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1]  
    label = int(n_label);
    print(f"current sound start:{start} to end:{end}");
    print(f"label is {label} and sound len is {len(sound)}")
    sound = np.float32(preprocess(sound, _funcs));
    sounds.append(sound);
    labels.append(label);

print(f"sounds length: {len(sounds)}");
print(f"labels length: {len(labels)}");

# sound = wavio.read(test_sound_file).data.T[0]
# start = sound.nonzero()[0].min()
# end = sound.nonzero()[0].max()
# sound = sound[start: end + 1]  # Remove silent sections
# label = 18 #int(os.path.splitext(test_sound_file)[0].split('-')[-1])

# if len(sound)> 220500:
#     sound = sound[:220500]

# ec50_sound1 =  wavio.read(ec50_18_sound).data.T[0]
# start_ec50 = ec50_sound1.nonzero()[0].min()
# end_ec50 = ec50_sound1.nonzero()[0].max()
# ec50_sound1 = ec50_sound1[start_ec50:end_ec50+1]
# ec50_18_label = 18
# Out:
# total alarm sounds:60
# total other sounds:89
# current sound start:0 to end:119993
# label is 52 and sound len is 119994
# strind = 119993
# clip-1 range: 0 to 30225
# clip-2 range: 119993 to 150218
# current sound start:0 to end:83695
# label is 52 and sound len is 83696
# strind = 83695
# clip-1 range: 0 to 30225
# clip-2 range: 83695 to 113920
# current sound start:1 to end:99999
# label is 52 and sound len is 99999
# strind = 99998
# clip-1 range: 0 to 30225
# clip-2 range: 99998 to 130223
# current sound start:8691 to end:99999
# label is 52 and sound len is 91309
# strind = 91308
# clip-1 range: 0 to 30225
# clip-2 range: 91308 to 121533
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:77954
# label is 52 and sound len is 77955
# strind = 77954
# clip-1 range: 0 to 30225
# clip-2 range: 77954 to 108179
# current sound start:0 to end:65999
# label is 52 and sound len is 66000
# strind = 65999
# clip-1 range: 0 to 30225
# clip-2 range: 65999 to 96224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:96555
# label is 52 and sound len is 96556
# strind = 96555
# clip-1 range: 0 to 30225
# clip-2 range: 96555 to 126780
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:3 to end:99999
# label is 52 and sound len is 99997
# strind = 99996
# clip-1 range: 0 to 30225
# clip-2 range: 99996 to 130221
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:2 to end:99999
# label is 52 and sound len is 99998
# strind = 99997
# clip-1 range: 0 to 30225
# clip-2 range: 99997 to 130222
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:2 to end:99999
# label is 52 and sound len is 99998
# strind = 99997
# clip-1 range: 0 to 30225
# clip-2 range: 99997 to 130222
# current sound start:327 to end:78288
# label is 52 and sound len is 77962
# strind = 77961
# clip-1 range: 0 to 30225
# clip-2 range: 77961 to 108186
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:1 to end:99999
# label is 52 and sound len is 99999
# strind = 99998
# clip-1 range: 0 to 30225
# clip-2 range: 99998 to 130223
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:108828
# label is 52 and sound len is 108829
# strind = 108828
# clip-1 range: 0 to 30225
# clip-2 range: 108828 to 139053
# current sound start:0 to end:99997
# label is 52 and sound len is 99998
# strind = 99997
# clip-1 range: 0 to 30225
# clip-2 range: 99997 to 130222
# current sound start:0 to end:109293
# label is 52 and sound len is 109294
# strind = 109293
# clip-1 range: 0 to 30225
# clip-2 range: 109293 to 139518
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:75 to end:99999
# label is 52 and sound len is 99925
# strind = 99924
# clip-1 range: 0 to 30225
# clip-2 range: 99924 to 130149
# current sound start:0 to end:89999
# label is 52 and sound len is 90000
# strind = 89999
# clip-1 range: 0 to 30225
# clip-2 range: 89999 to 120224
# current sound start:0 to end:75038
# label is 52 and sound len is 75039
# strind = 75038
# clip-1 range: 0 to 30225
# clip-2 range: 75038 to 105263
# current sound start:0 to end:95999
# label is 52 and sound len is 96000
# strind = 95999
# clip-1 range: 0 to 30225
# clip-2 range: 95999 to 126224
# current sound start:3 to end:111839
# label is 52 and sound len is 111837
# strind = 111836
# clip-1 range: 0 to 30225
# clip-2 range: 111836 to 142061
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:2 to end:99999
# label is 52 and sound len is 99998
# strind = 99997
# clip-1 range: 0 to 30225
# clip-2 range: 99997 to 130222
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:97989
# label is 52 and sound len is 97990
# strind = 97989
# clip-1 range: 0 to 30225
# clip-2 range: 97989 to 128214
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99997
# label is 52 and sound len is 99998
# strind = 99997
# clip-1 range: 0 to 30225
# clip-2 range: 99997 to 130222
# current sound start:0 to end:56886
# label is 52 and sound len is 56887
# strind = 56886
# clip-1 range: 0 to 30225
# clip-2 range: 56886 to 87111
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99998
# label is 52 and sound len is 99999
# strind = 99998
# clip-1 range: 0 to 30225
# clip-2 range: 99998 to 130223
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:100004
# label is 52 and sound len is 100005
# strind = 100004
# clip-1 range: 0 to 30225
# clip-2 range: 100004 to 130229
# current sound start:10 to end:99999
# label is 52 and sound len is 99990
# strind = 99989
# clip-1 range: 0 to 30225
# clip-2 range: 99989 to 130214
# current sound start:1045 to end:79002
# label is 52 and sound len is 77958
# strind = 77957
# clip-1 range: 0 to 30225
# clip-2 range: 77957 to 108182
# current sound start:0 to end:99999
# label is 52 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:30391
# label is 99 and sound len is 30392
# strind = 30391
# clip-1 range: 0 to 30225
# clip-2 range: 30391 to 60616
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:23 to end:21663
# label is 99 and sound len is 21641
# strind = 21640
# clip-1 range: 0 to 30225
# clip-2 range: 21640 to 51865
# current sound start:0 to end:59353
# label is 99 and sound len is 59354
# strind = 59353
# clip-1 range: 0 to 30225
# clip-2 range: 59353 to 89578
# current sound start:0 to end:7446
# label is 99 and sound len is 7447
# strind = 7446
# clip-1 range: 0 to 30225
# clip-2 range: 7446 to 37671
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:7 to end:27999
# label is 99 and sound len is 27993
# strind = 27992
# clip-1 range: 0 to 30225
# clip-2 range: 27992 to 58217
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:18224
# label is 99 and sound len is 18225
# strind = 18224
# clip-1 range: 0 to 30225
# clip-2 range: 18224 to 48449
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:77760
# label is 99 and sound len is 77761
# strind = 77760
# clip-1 range: 0 to 30225
# clip-2 range: 77760 to 107985
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:6377 to end:99999
# label is 99 and sound len is 93623
# strind = 93622
# clip-1 range: 0 to 30225
# clip-2 range: 93622 to 123847
# current sound start:0 to end:26457
# label is 99 and sound len is 26458
# strind = 26457
# clip-1 range: 0 to 30225
# clip-2 range: 26457 to 56682
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:19 to end:22526
# label is 99 and sound len is 22508
# strind = 22507
# clip-1 range: 0 to 30225
# clip-2 range: 22507 to 52732
# current sound start:14 to end:99999
# label is 99 and sound len is 99986
# strind = 99985
# clip-1 range: 0 to 30225
# clip-2 range: 99985 to 130210
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:75179
# label is 99 and sound len is 75180
# strind = 75179
# clip-1 range: 0 to 30225
# clip-2 range: 75179 to 105404
# current sound start:0 to end:99796
# label is 99 and sound len is 99797
# strind = 99796
# clip-1 range: 0 to 30225
# clip-2 range: 99796 to 130021
# current sound start:0 to end:80379
# label is 99 and sound len is 80380
# strind = 80379
# clip-1 range: 0 to 30225
# clip-2 range: 80379 to 110604
# current sound start:0 to end:69681
# label is 99 and sound len is 69682
# strind = 69681
# clip-1 range: 0 to 30225
# clip-2 range: 69681 to 99906
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:41784
# label is 99 and sound len is 41785
# strind = 41784
# clip-1 range: 0 to 30225
# clip-2 range: 41784 to 72009
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:19283
# label is 99 and sound len is 19284
# strind = 19283
# clip-1 range: 0 to 30225
# clip-2 range: 19283 to 49508
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:46122
# label is 99 and sound len is 46123
# strind = 46122
# clip-1 range: 0 to 30225
# clip-2 range: 46122 to 76347
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:79698
# label is 99 and sound len is 79699
# strind = 79698
# clip-1 range: 0 to 30225
# clip-2 range: 79698 to 109923
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:247 to end:99999
# label is 99 and sound len is 99753
# strind = 99752
# clip-1 range: 0 to 30225
# clip-2 range: 99752 to 129977
# current sound start:1362 to end:99541
# label is 99 and sound len is 98180
# strind = 98179
# clip-1 range: 0 to 30225
# clip-2 range: 98179 to 128404
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:38020
# label is 99 and sound len is 38021
# strind = 38020
# clip-1 range: 0 to 30225
# clip-2 range: 38020 to 68245
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:36235
# label is 99 and sound len is 36236
# strind = 36235
# clip-1 range: 0 to 30225
# clip-2 range: 36235 to 66460
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:19482
# label is 99 and sound len is 19483
# strind = 19482
# clip-1 range: 0 to 30225
# clip-2 range: 19482 to 49707
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:4 to end:99999
# label is 99 and sound len is 99996
# strind = 99995
# clip-1 range: 0 to 30225
# clip-2 range: 99995 to 130220
# current sound start:0 to end:90621
# label is 99 and sound len is 90622
# strind = 90621
# clip-1 range: 0 to 30225
# clip-2 range: 90621 to 120846
# current sound start:0 to end:59463
# label is 99 and sound len is 59464
# strind = 59463
# clip-1 range: 0 to 30225
# clip-2 range: 59463 to 89688
# current sound start:0 to end:51470
# label is 99 and sound len is 51471
# strind = 51470
# clip-1 range: 0 to 30225
# clip-2 range: 51470 to 81695
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:80958
# label is 99 and sound len is 80959
# strind = 80958
# clip-1 range: 0 to 30225
# clip-2 range: 80958 to 111183
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:49918
# label is 99 and sound len is 49919
# strind = 49918
# clip-1 range: 0 to 30225
# clip-2 range: 49918 to 80143
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# current sound start:0 to end:99999
# label is 99 and sound len is 100000
# strind = 99999
# clip-1 range: 0 to 30225
# clip-2 range: 99999 to 130224
# sounds length: 149
# labels length: 149

# %%
print(sounds)
print(labels)
# Out:
# [array([[ 0.        ,  0.        ,  0.        , ..., -0.19067383,
#         -0.13583374,  0.07992554],
#        [ 0.10272217, -0.00878906, -0.19595337, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.13998413,
#         -0.02075195,  0.10272217],
#        [ 0.30545044,  0.32110596,  0.27816772, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.01455688,
#         -0.05999756,  0.01202393],
#        [ 0.01501465,  0.00579834, -0.01550293, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.02282715, -0.00119019, -0.0116272 , ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.09228516,
#          0.16952515,  0.1210022 ],
#        [-0.2772522 , -0.26135254, -0.1680603 , ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.01681519,
#          0.05639648,  0.09945679],
#        [-0.06924438, -0.06484985, -0.02108765, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.318573  ,
#         -0.02801514,  0.28353882],
#        [ 0.03616333,  0.22665405,  0.18444824, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.00299072,
#          0.00302124,  0.00302124],
#        [-0.00338745, -0.00317383, -0.00317383, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.08737183,
#         -0.11526489, -0.04086304],
#        [ 0.1882019 ,  0.22232056,  0.14328003, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.15213013,
#         -0.0184021 ,  0.12356567],
#        [-0.25531006, -0.15249634, -0.03439331, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.13818359,
#         -0.08023071, -0.01623535],
#        [-0.05166626, -0.04852295, -0.04330444, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.13613892,
#         -0.43533325, -0.56698608],
#        [-0.39508057, -0.41781616, -0.41104126, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.70932007,
#         -0.52770996, -0.45898438],
#        [ 0.17855835,  0.09771729,  0.22955322, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0
...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.03994751,
#         -0.04190063, -0.0395813 ],
#        [-0.08447266, -0.05487061, -0.0213623 , ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.06582642,
#          0.0184021 ,  0.03030396],
#        [-0.0713501 , -0.04428101,  0.02954102, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.18811035,
#          0.18490601,  0.16845703],
#        [-0.14746094, -0.04992676,  0.06503296, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.31231689,
#         -0.65734863, -0.77151489],
#        [-0.22589111, -0.88006592, -0.99139404, ...,  0.        ,
#          0.        ,  0.        ]]), array([[0.        , 0.        , 0.        , ..., 0.24121094, 0.18347168,
#         0.11590576],
#        [0.19519043, 0.1194458 , 0.08068848, ..., 0.        , 0.        ,
#         0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.01654053,
#         -0.01821899,  0.01263428],
#        [ 0.22888184,  0.47473145,  0.13122559, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.02450562,
#          0.0262146 ,  0.02322388],
#        [ 0.2684021 ,  0.04244995, -0.26547241, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.14627075,
#          0.15231323,  0.15106201],
#        [-0.16372681, -0.2208252 , -0.02740479, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.02148438,
#          0.01702881,  0.01266479],
#        [-0.00827026, -0.00186157,  0.00292969, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.00054932,
#          0.00720215,  0.0062561 ],
#        [-0.0553894 , -0.05307007, -0.05065918, ...,  0.        ,
#          0.        ,  0.        ]]), array([[0.        , 0.        , 0.        , ..., 0.0010376 , 0.0043335 ,
#         0.00234985],
#        [0.1104126 , 0.07562256, 0.06314087, ..., 0.        , 0.        ,
#         0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.03271484,
#          0.12280273,  0.10681152],
#        [-0.00360107, -0.00335693, -0.00320435, ...,  0.        ,
#          0.        ,  0.        ]]), array([[0.        , 0.        , 0.        , ..., 0.26834106, 0.37716675,
#         0.34570312],
#        [0.16552734, 0.10321045, 0.07247925, ..., 0.        , 0.        ,
#         0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.02859497,
#         -0.0401001 , -0.05401611],
#        [-0.14724731, -0.15341187, -0.16171265, ...,  0.        ,
#          0.        ,  0.        ]]), array([[0.        , 0.        , 0.        , ..., 0.22537231, 0.17642212,
#         0.13467407],
#        [0.20397949, 0.20910645, 0.20202637, ..., 0.        , 0.        ,
#         0.        ]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.14175415,
#          0.05712891, -0.0229187 ],
#        [ 0.00634766, -0.00308228, -0.01037598, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.        ,  0.        ,  0.        , ..., -0.17733765,
#         -0.10043335, -0.05743408],
#        [-0.07098389, -0.0619812 , -0.01751709, ...,  0.        ,
#          0.        ,  0.        ]]), array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          1.65527344e-01, -1.65222168e-01, -3.62976074e-01],
#        [-1.49536133e-03,  6.10351562e-05,  1.12915039e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]), array([[ 0.        ,  0.        ,  0.        , ...,  0.00067139,
#          0.00039673,  0.00115967],
#        [-0.00082397,  0.00036621,  0.00091553, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.00479126,
#         -0.0057373 , -0.00582886],
#        [ 0.01055908,  0.00848389,  0.00704956, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.32583618,
#          0.3416443 ,  0.36727905],
#        [-0.02584839, -0.02761841, -0.0305481 , ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.325531  ,
#         -0.19561768,  0.12442017],
#        [-0.3012085 , -0.13565063,  0.04196167, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.00076294,
#         -0.00061035, -0.00067139],
#        [-0.0010376 , -0.00067139, -0.00042725, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.01556396,
#         -0.05706787, -0.03161621],
#        [-0.08703613,  0.03158569,  0.22122192, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.11129761,
#          0.13232422,  0.11837769],
#        [-0.00631714, -0.01141357, -0.00140381, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.
..., 0.        , 0.        ,
#         0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.04452515,
#         -0.05047607, -0.05609131],
#        [ 0.03268433,  0.05606079,  0.07373047, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[0.        , 0.        , 0.        , ..., 0.02059937, 0.01068115,
#         0.01339722],
#        [0.01815796, 0.02767944, 0.02282715, ..., 0.        , 0.        ,
#         0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.06182861,
#         -0.09481812,  0.03079224],
#        [-0.00396729, -0.00396729, -0.01077271, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.54537964,
#          0.71258545,  0.7875061 ],
#        [ 0.3031311 ,  0.021698  , -0.22598267, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.00061035,
#         -0.0007019 , -0.00094604],
#        [-0.01638794, -0.01202393, -0.01049805, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.00332642,
#          0.0012207 , -0.00164795],
#        [-0.00064087, -0.00125122, -0.00088501, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.04873657,
#         -0.00964355, -0.065979  ],
#        [ 0.02120972,  0.04660034,  0.06817627, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.03585815,
#          0.01422119,  0.01651001],
#        [-0.00027466, -0.00039673, -0.00033569, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.00906372,
#          0.0163269 ,  0.01721191],
#        [-0.03640747, -0.03533936, -0.03588867, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          0.0000000e+00, -3.0517578e-05,  0.0000000e+00],
#        [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00]], dtype=float32), array([[0.        , 0.        , 0.        , ..., 0.0005188 , 0.00045776,
#         0.        ],
#        [0.01861572, 0.01959229, 0.01885986, ..., 0.        , 0.        ,
#         0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.10220337,
#         -0.17468262,  0.23132324],
#        [ 0.06530762,  0.01852417,  0.06454468, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.01885986,
#         -0.01766968, -0.01519775],
#        [-0.04318237,  0.13137817,  0.16854858, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.0017395 ,
#         -0.00204468, -0.00164795],
#        [ 0.10745239,  0.10717773,  0.10699463, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.02999878,
#         -0.21478271, -0.2956848 ],
#        [-0.26281738, -0.2741394 , -0.28427124, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[0.        , 0.        , 0.        , ..., 0.00024414, 0.00027466,
#         0.00027466],
#        [0.00045776, 0.0007019 , 0.00061035, ..., 0.        , 0.        ,
#         0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ...,  0.0083313 ,
#          0.00042725, -0.00778198],
#        [ 0.00234985,  0.00137329, -0.0007019 , ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[ 0.        ,  0.        ,  0.        , ..., -0.05715942,
#         -0.05593872, -0.04504395],
#        [-0.00228882, -0.00085449, -0.00314331, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32), array([[0.        , 0.        , 0.        , ..., 0.00146484, 0.01403809,
#         0.01986694],
#        [0.02078247, 0.02279663, 0.01870728, ..., 0.        , 0.        ,
#         0.        ]], dtype=float32)]
# [52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 52, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99]

# %%
print(sounds[0][1].shape)
print(type(labels[0]))
# Out:
# (30225,)
# <class 'int'>

# %%
# sound = np.expand_dims(sound, axis=1)
# sound = np.expand_dims(sound, axis=3)
# print(sound.shape)

# %%
test_len = len(sounds);
p_total_len = len(p_wav_list);
n_total_len = len(n_wav_list);
correct_num = 0;
p_correct_num = 0;
n_correct_num = 0;
n_correct_siren_num = 0;
n_correct_othersounds_num = 0;
for w in range(test_len): 
    s = sounds[w]
    l = labels[w]
    s_test = np.expand_dims(s[1], axis=0);
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    s_test = np.float32(s_test);
    # print(s_test.shape)
    # print(f"the {w+1} item's shape:\n  {s.shape}");
    # Run inference
    # print(f"s type:{type(s)}, and s shape:{s.shape}")
    tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter_quant.invoke()
    pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
    # print(f"Prediction result shape:{pred.shape}\n");
    print(f"Prediction result: {pred}, and true label: {l}")
    if l == 52: #positive
        if pred[0][0] > pred[0][1]:
            correct_num += 1;
            p_correct_num += 1;
    if l == 99: #negative
        if pred[0][0] < pred[0][1]:
            correct_num += 1;
            n_correct_num += 1;
print(f"total sounds result is {100*(correct_num/test_len)}");
print(f"total alarm sounds result is {100*(p_correct_num/p_total_len)}");
print(f"total siren sound result is {100*(n_correct_num/n_total_len)}");
# Out:
# Prediction result: [[0.6335465  0.36645353]], and true label: 52
# Prediction result: [[9.998073e-01 1.927186e-04]], and true label: 52
# Prediction result: [[0.58471596 0.415284  ]], and true label: 52
# Prediction result: [[0.04692966 0.95307034]], and true label: 52
# Prediction result: [[0.01854026 0.98145974]], and true label: 52
# Prediction result: [[0.9945186  0.00548147]], and true label: 52
# Prediction result: [[0.99056107 0.00943898]], and true label: 52
# Prediction result: [[0.08354372 0.91645634]], and true label: 52
# Prediction result: [[0.94991285 0.05008713]], and true label: 52
# Prediction result: [[9.999982e-01 1.836752e-06]], and true label: 52
# Prediction result: [[0.8929671  0.10703287]], and true label: 52
# Prediction result: [[0.5 0.5]], and true label: 52
# Prediction result: [[0.32022026 0.6797797 ]], and true label: 52
# Prediction result: [[0.9922994  0.00770064]], and true label: 52
# Prediction result: [[9.9999225e-01 7.7297682e-06]], and true label: 52
# Prediction result: [[0.38248146 0.61751854]], and true label: 52
# Prediction result: [[0.98484856 0.01515141]], and true label: 52
# Prediction result: [[0.9801726 0.0198274]], and true label: 52
# Prediction result: [[0.36645353 0.6335465 ]], and true label: 52
# Prediction result: [[0.9941326  0.00586744]], and true label: 52
# Prediction result: [[0.99280506 0.00719495]], and true label: 52
# Prediction result: [[0.58471596 0.415284  ]], and true label: 52
# Prediction result: [[0.9704038  0.02959616]], and true label: 52
# Prediction result: [[0.9917584  0.00824157]], and true label: 52
# Prediction result: [[9.9933976e-01 6.6020584e-04]], and true label: 52
# Prediction result: [[0.7227327  0.27726725]], and true label: 52
# Prediction result: [[9.9968886e-01 3.1110839e-04]], and true label: 52
# Prediction result: [[9.9977905e-01 2.2097917e-04]], and true label: 52
# Prediction result: [[9.9933976e-01 6.6020584e-04]], and true label: 52
# Prediction result: [[0.6647038  0.33529624]], and true label: 52
# Prediction result: [[0.99521637 0.00478368]], and true label: 52
# Prediction result: [[0.98266476 0.0173352 ]], and true label: 52
# Prediction result: [[0.05008713 0.94991285]], and true label: 52
# Prediction result: [[9.994242e-01 5.758061e-04]], and true label: 52
# Prediction result: [[0.46583694 0.53416306]], and true label: 52
# Prediction result: [[9.9987221e-01 1.2782973e-04]], and true label: 52
# Prediction result: [[0.02769277 0.97230726]], and true label: 52
# Prediction result: [[9.9996746e-01 3.2529297e-05]], and true label: 52
# Prediction result: [[0.9858366  0.01416343]], and true label: 52
# Prediction result: [[0.9986921  0.00130797]], and true label: 52
# Prediction result: [[9.999510e-01 4.904413e-05]], and true label: 52
# Prediction result: [[0.04396204 0.956038  ]], and true label: 52
# Prediction result: [[9.999825e-01 1.757121e-05]], and true label: 52
# Prediction result: [[9.9998462e-01 1.5323665e-05]], and true label: 52
# Prediction result: [[0.97230726 0.02769277]], and true label: 52
# Prediction result: [[9.998073e-01 1.927186e-04]], and true label: 52
# Prediction result: [[9.9998915e-01 1.0883402e-05]], and true label: 52
# Prediction result: [[0.9704038  0.02959616]], and true label: 52
# Prediction result: [[0.98484856 0.01515141]], and true label: 52
# Prediction result: [[0.99582565 0.00417434]], and true label: 52
# Prediction result: [[0.9876258  0.01237417]], and true label: 52
# Prediction result: [[9.9998116e-01 1.8815732e-05]], and true label: 52
# Prediction result: [[0.06483512 0.9351648 ]], and true label: 52
# Prediction result: [[0.82834625 0.17165373]], and true label: 52
# Prediction result: [[9.9997687e-01 2.3103557e-05]], and true label: 52
# Prediction result: [[0.99521637 0.00478368]], and true label: 52
# Prediction result: [[0.1919969  0.80800307]], and true label: 52
# Prediction result: [[9.9996519e-01 3.4833225e-05]], and true label: 52
# Prediction result: [[0.99758124 0.00241876]], and true label: 52
# Prediction result: [[9.9983191e-01 1.6807162e-04]], and true label: 52
# Prediction result: [[0.02590852 0.9740915 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.17165373 0.82834625]], and true label: 99
# Prediction result: [[0.05008713 0.94991285]], and true label: 99
# Prediction result: [[0.3987692 0.6012308]], and true label: 99
# Prediction result: [[0.03379046 0.96620953]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.99280506 0.00719495]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.92635554 0.07364443]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.0198274 0.9801726]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02590852 0.9740915 ]], and true label: 99
# Prediction result: [[0.12083481 0.8791652 ]], and true label: 99
# Prediction result: [[0.04396204 0.956038  ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02266964 0.9773303 ]], and true label: 99
# Prediction result: [[0.1361452 0.8638548]], and true label: 99
# Prediction result: [[0.25069234 0.7493076 ]], and true label: 99
# Prediction result: [[0.03379046 0.96620953]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.03379046 0.96620953]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.10703287 0.8929671 ]], and true label: 99
# Prediction result: [[0.2028374 0.7971626]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02959616 0.9704038 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02266964 0.9773303 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.5 0.5]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.0198274 0.9801726]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.9704038  0.02959616]], and true label: 99
# Prediction result: [[0.96620953 0.03379046]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.30551058 0.69448936]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.99056107 0.00943898]], and true label: 99
# Prediction result: [[0.17165373 0.82834625]], and true label: 99
# Prediction result: [[0.22586854 0.7741315 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02120197 0.978798  ]], and true label: 99
# Prediction result: [[0.02590852 0.9740915 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.04396204 0.956038  ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.99815935 0.00184062]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.02266964 0.9773303 ]], and true label: 99
# Prediction result: [[0.03379046 0.96620953]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[9.9988854e-01 1.1148053e-04]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.53416306 0.46583694]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.18160376 0.8183962 ]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# Prediction result: [[0.01854026 0.98145974]], and true label: 99
# total sounds result is 85.23489932885906
# total alarm sounds result is 78.33333333333333
# total siren sound result is 89.8876404494382

# %%
# scores = model.predict(sound, batch_size=len(sound), verbose=0);
# print(type(scores))
# print(scores.shape)

# for res in scores:
#     max_value = res.max()
#     max_index = np.argmax(res)
#     print(f"max value:{max_value:.5f} and index is {max_index}")
#     print('\n'.join('{}: {:.5f}'.format(*k) for k in enumerate(res)))
