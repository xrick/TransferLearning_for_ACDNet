# %% [markdown]
# ## 測試項目
# 1. 訓練集中的alarm聲
# 2. 使用pruned and quantized tflite model
# 4. export to cc file

# %%
import os
import sys
import datetime
import shutil
import numpy as np
import tensorflow as tf
# from tensorflow import keras
import zipfile
import wavio
from common import utils as U
np.set_printoptions(threshold=sys.maxsize)
# Out:
# 2024-01-22 17:09:21.405007: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-22 17:09:21.425715: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-22 17:09:21.425737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-22 17:09:21.426347: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-22 17:09:21.429910: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 17:09:21.789468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from datetime import datetime
import re

# %% [markdown]
# ### Loading TFlite Model

# %%
tflite_quant_model_path = "./models/tflite/acdnet_ori_97.7_to_quant_86.3_202401221042.tflite";
# Load quantized TFLite model
tflite_interpreter_quant = tf.lite.Interpreter(model_path=tflite_quant_model_path)

# %%
# model.summary()
input_details = tflite_interpreter_quant.get_input_details()
output_details = tflite_interpreter_quant.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

#resize the input and output
# tflite_interpreter_quant.resize_tensor_input(input_details[0]['index'], (2, 1, 30225, 1))
# tflite_interpreter_quant.resize_tensor_input(output_details[0]['index'], (2, 2))

# input_details = tflite_interpreter_quant.get_input_details()
# output_details = tflite_interpreter_quant.get_output_details()

# print("== Input details ==")
# print("name:", input_details[0]['name'])
# print("shape:", input_details[0]['shape'])
# print("type:", input_details[0]['dtype'])

# print("\n== Output details ==")
# print("name:", output_details[0]['name'])
# print("shape:", output_details[0]['shape'])
# print("type:", output_details[0]['dtype'])

tflite_interpreter_quant.allocate_tensors();
# Out:
# == Input details ==
# name: x.3
# shape: [    1     1 30225     1]
# type: <class 'numpy.float32'>
#
# == Output details ==
# name: 185
# shape: [1 2]
# type: <class 'numpy.float32'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### loading dataset from npz format
# 1. ACDNet input length is 30225
# 2. sr is 44100 and 20000
# 3. need to convert 16K to 20000
# ### ACDNet Config Setting
# #### Training Parameters
# 1. opt.batchSize = 64;
# 2. opt.weightDecay = 5e-4;
# 3. opt.momentum = 0.9;
# 4. opt.nEpochs = 2000;
# 5. opt.LR = 0.1;
# 6. opt.schedule = [0.3, 0.6, 0.9];
# 7. opt.warmup = 10;
# #### Basic Net Configuration
# - nClasses = 50
# - nFolds = 5
# - splits = \[i for in range(1, nFolds + 1)\]
# - sr = 20000
# - inputLength = 30225
# <br>ngth = 30225;
# ### How to convert 16K sound to 44.1K with python and sox
#
# if using sox the command is as following: <br />
#     sox old.wav -b 16 new.wav
# if using python you can do as following: <br />
#     import soundfile
#
# data, samplerate = soundfile.read('old.wav
#     <br />)
# soundfile.write('new.wav', data, samplerate, subtype='PCM_1
# 6')

# %%
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def getFileList(srcDir,regex='.*\.wav'):
    results = os.listdir(srcDir)
    out_files = []
    cnt_files = 0
    for file in results:
        if os.path.isdir(os.path.join(srcDir, file)):
            out_files += getFileList(os.path.join(srcDir, file))
        elif re.match(regex, file,  re.I):  # file.startswith(startExtension) or file.endswith(".txt") or file.endswith(endExtension):
            out_files.append(os.path.join(srcDir, file))
            cnt_files = cnt_files + 1
    return out_files

# %% [markdown]
# ## sound preprocessing functions

# %%
_inputLen = 30225
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess_debug():
    debug_funcs = []
    debug_funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),]
              # U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return debug_funcs

def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)

    return sound;

# %%
_funcs = preprocess_setup()
# _debug_funcs = preprocess_debug()

# %% [markdown]
# ### Read Test Wav File

# %%
# for i in p_wav_list:
#     sound = wavio.read(i).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1]
#     sound_debug = np.array(preprocess(sound,_debug_funcs));
#     print(f"sound content after pad and normalize:\n{sound_debug}")
#     label = int(p_label);
#     print(f"current sound start:{start} to end:{end}");
#     label = int(p_label);
#     if len(sound)> 220500:
#         sound = sound[:220500]
#     sound = preprocess(sound, _funcs);
#     print(f"label is {label} and sound len is {len(sound)}");
#     sounds.append(sound);
#     labels.append(label);
    
# for j in n_wav_list:
#     sound = wavio.read(j).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1];
#     sound_debug = np.array(preprocess(sound,_debug_funcs));
#     print(f"sound content after pad and normalize:\n{sound_debug}")
#     label = int(n_label);
#     print(f"current sound start:{start} to end:{end}");
    
#     sound = np.float32(preprocess(sound, _funcs));
#     print(f"label is {label} and sound len is {len(sound)}")
#     sounds.append(sound);
#     labels.append(label);

# %%
positive_test_wavs = "./test_sounds/positive/"
negative_test_wavs_others = "./test_sounds/negative/othersounds/"
negative_test_wavs_siren = "./test_sounds/negative/siren/"

p_wav_list = getFileList(positive_test_wavs);
n_wav_list_other = getFileList(negative_test_wavs_others);
n_wav_list_siren = getFileList(negative_test_wavs_siren);
# print(f"total alarm sounds:{len(p_wav_list)} ");
# print(f"total other sounds:{len(n_wav_list)}")
p_label = 52;
n_label = 99;

sounds = [];
labels = [];
## sound = preprocess(sound, _funcs)
for i in p_wav_list:
    sound = wavio.read(i).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1]
    label = int(p_label);
    if len(sound)> 220500:
        sound = sound[:220500]
    sound = preprocess(sound, _funcs);
    sounds.append(sound);
    labels.append(label);
    
for j in n_wav_list_other:
    sound = wavio.read(j).data.T[0]
    start = sound.nonzero()[0].min();
    end = sound.nonzero()[0].max();
    sound = sound[start: end + 1];
    label = int(n_label);
    sound = np.float32(preprocess(sound, _funcs));
    sounds.append(sound);
    labels.append(label);

# for k in n_wav_list_siren:
#     sound = wavio.read(j).data.T[0]
#     start = sound.nonzero()[0].min();
#     end = sound.nonzero()[0].max();
#     sound = sound[start: end + 1];
#     label = int(n_label);
#     sound = np.float32(preprocess(sound, _funcs));
#     sounds.append(sound);
#     labels.append(label);

print(f"sounds length: {len(sounds)}");
print(f"labels length: {len(labels)}");

# sound = wavio.read(test_sound_file).data.T[0]
# start = sound.nonzero()[0].min()
# end = sound.nonzero()[0].max()
# sound = sound[start: end + 1]  # Remove silent sections
# label = 18 #int(os.path.splitext(test_sound_file)[0].split('-')[-1])

# if len(sound)> 220500:
#     sound = sound[:220500]

# ec50_sound1 =  wavio.read(ec50_18_sound).data.T[0]
# start_ec50 = ec50_sound1.nonzero()[0].min()
# end_ec50 = ec50_sound1.nonzero()[0].max()
# ec50_sound1 = ec50_sound1[start_ec50:end_ec50+1]
# ec50_18_label = 18
# Out:
# sounds length: 244
# labels length: 244

# %%
# print(sounds)
# print(labels)

# %%
print(sounds[0][1].shape)
print(type(labels[0]))
# Out:
# (30225,)
# <class 'int'>

# %%
# sound = np.expand_dims(sound, axis=1)
# sound = np.expand_dims(sound, axis=3)
# print(sound.shape)

# %%
test_len = len(sounds);
p_total_len = len(p_wav_list);
n_total_len = len(n_wav_list_other);
print(f"total alarm sounds is {p_total_len}\n total other sounds is {n_total_len}")
correct_num = 0;
p_correct_num = 0;
n_correct_num = 0;
n_correct_siren_num = 0;
n_correct_othersounds_num = 0;
for w in range(test_len): 
    s = sounds[w]
    l = labels[w]
    s_test = np.expand_dims(s[1], axis=0);
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    s_test = np.float32(s_test);
    # print(s_test.shape)
    # print(f"the {w+1} item's shape:\n  {s.shape}");
    # Run inference
    # print(f"s type:{type(s)}, and s shape:{s.shape}")
    tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter_quant.invoke()
    pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
    # print(f"Prediction result shape:{pred.shape}\n");
    print(f"Prediction result: {pred}, and true label: {l}")
    if l == 52: #positive
        if pred[0][0] > pred[0][1]:
            correct_num += 1;
            p_correct_num += 1;
    if l == 99: #negative
        if pred[0][0] < pred[0][1]:
            correct_num += 1;
            n_correct_num += 1;
print(f"total sounds result is {100*(correct_num/test_len)}");
print(f"total alarm sounds result is {100*(p_correct_num/p_total_len)}");
print(f"total other sounds result is {100*n_correct_num/n_total_len}");
# Out:
# total alarm sounds is 116
#  total other sounds is 128
# Prediction result: [[0.1681896  0.83181036]], and true label: 52
# Prediction result: [[9.9972564e-01 2.7428617e-04]], and true label: 52
# Prediction result: [[0.9876117  0.01238833]], and true label: 52
# Prediction result: [[0.09761436 0.9023857 ]], and true label: 52
# Prediction result: [[9.999902e-01 9.761153e-06]], and true label: 52
# Prediction result: [[0.9985475  0.00145245]], and true label: 52
# Prediction result: [[0.9551276  0.04487232]], and true label: 52
# Prediction result: [[0.21073337 0.7892666 ]], and true label: 52
# Prediction result: [[0.05122116 0.9487788 ]], and true label: 52
# Prediction result: [[0.993334   0.00666605]], and true label: 52
# Prediction result: [[0.9719285 0.0280715]], and true label: 52
# Prediction result: [[0.5 0.5]], and true label: 52
# Prediction result: [[0.51736814 0.48263183]], and true label: 52
# Prediction result: [[0.9918012  0.00819878]], and true label: 52
# Prediction result: [[0.9632624  0.03673757]], and true label: 52
# Prediction result: [[0.5519374 0.4480626]], and true label: 52
# Prediction result: [[0.85900056 0.14099938]], and true label: 52
# Prediction result: [[0.9952815  0.00471847]], and true label: 52
# Prediction result: [[0.9334554 0.0665446]], and true label: 52
# Prediction result: [[0.98478335 0.01521663]], and true label: 52
# Prediction result: [[0.63552755 0.36447245]], and true label: 52
# Prediction result: [[0.98132163 0.01867842]], and true label: 52
# Prediction result: [[0.36447245 0.63552755]], and true label: 52
# Prediction result: [[0.8894383  0.11056171]], and true label: 52
# Prediction result: [[0.994194 0.005806]], and true label: 52
# Prediction result: [[0.11758346 0.88241655]], and true label: 52
# Prediction result: [[0.9977977 0.0022023]], and true label: 52
# Prediction result: [[0.63552755 0.36447245]], and true label: 52
# Prediction result: [[0.9551276  0.04487232]], and true label: 52
# Prediction result: [[9.9985325e-01 1.4675950e-04]], and true label: 52
# Prediction result: [[9.9984264e-01 1.5732042e-04]], and true label: 52
# Prediction result: [[0.92900604 0.07099398]], and true label: 52
# Prediction result: [[9.5766521e-04 9.9904233e-01]], and true label: 52
# Prediction result: [[0.02623621 0.9737638 ]], and true label: 52
# Prediction result: [[0.02290946 0.9770906 ]], and true label: 52
# Prediction result: [[0.97548217 0.02451789]], and true label: 52
# Prediction result: [[0.98132163 0.01867842]], and true label: 52
# Prediction result: [[0.05841336 0.9415867 ]], and true label: 52
# Prediction result: [[0.15868926 0.8413107 ]], and true label: 52
# Prediction result: [[0.97859573 0.02140423]], and true label: 52
# Prediction result: [[0.91927373 0.08072634]], and true label: 52
# Prediction result: [[0.99559695 0.00440306]], and true label: 52
# Prediction result: [[0.80059403 0.19940604]], and true label: 52
# Prediction result: [[0.9912163  0.00878368]], and true label: 52
# Prediction result: [[0.9825538  0.01744623]], and true label: 52
# Prediction result: [[0.9551276  0.04487232]], and true label: 52
# Prediction result: [[0.22252537 0.7774746 ]], and true label: 52
# Prediction result: [[9.9932325e-01 6.7673298e-04]], and true label: 52
# Prediction result: [[0.850371   0.14962903]], and true label: 52
# Prediction result: [[0.75250334 0.2474966 ]], and true label: 52
# Prediction result: [[0.01420949 0.9857905 ]], and true label: 52
# Prediction result: [[0.53469443 0.4653055 ]], and true label: 52
# Prediction result: [[0.19940604 0.80059403]], and true label: 52
# Prediction result: [[0.97859573 0.02140423]], and true label: 52
# Prediction result: [[0.97548217 0.02451789]], and true label: 52
# Prediction result: [[9.9977738e-01 2.2267715e-04]], and true label: 52
# Prediction result: [[9.999317e-01 6.833125e-05]], and true label: 52
# Prediction result: [[0.850371   0.14962903]], and true label: 52
# Prediction result: [[0.03435574 0.9656443 ]], and true label: 52
# Prediction result: [[0.9334554 0.0665446]], and true label: 52
# Prediction result: [[0.4653055  0.53469443]], and true label: 52
# Prediction result: [[0.9876117  0.01238833]], and true label: 52
# Prediction result: [[0.00252989 0.99747014]], and true label: 52
# Prediction result: [[0.6027659  0.39723408]], and true label: 52
# Prediction result: [[0.9867318  0.01326813]], and true label: 52
# Prediction result: [[0.63552755 0.36447245]], and true label: 52
# Prediction result: [[0.9989735  0.00102652]], and true label: 52
# Prediction result: [[0.11056171 0.8894383 ]], and true label: 52
# Prediction result: [[0.80059403 0.19940604]], and true label: 52
# Prediction result: [[9.9976128e-01 2.3869982e-04]], and true label: 52
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 52
# Prediction result: [[0.0012642  0.99873585]], and true label: 52
# Prediction result: [[0.96072215 0.03927783]], and true label: 52
# Prediction result: [[9.9966216e-01 3.3785283e-04]], and true label: 52
# Prediction result: [[0.63552755 0.36447245]], and true label: 52
# Prediction result: [[9.999862e-01 1.381713e-05]], and true label: 52
# Prediction result: [[0.95205295 0.04794704]], and true label: 52
# Prediction result: [[0.5 0.5]], and true label: 52
# Prediction result: [[0.3485305 0.6514695]], and true label: 52
# Prediction result: [[9.991665e-01 8.334899e-04]], and true label: 52
# Prediction result: [[0.9928576 0.0071424]], and true label: 52
# Prediction result: [[0.82186174 0.17813829]], and true label: 52
# Prediction result: [[0.9961662  0.00383385]], and true label: 52
# Prediction result: [[0.53469443 0.4653055 ]], and true label: 52
# Prediction result: [[0.9949437  0.00505635]], and true label: 52
# Prediction result: [[9.994505e-01 5.494414e-04]], and true label: 52
# Prediction result: [[0.98000413 0.01999588]], and true label: 52
# Prediction result: [[9.9974412e-01 2.5587514e-04]], and true label: 52
# Prediction result: [[9.9927455e-01 7.2540349e-04]], and true label: 52
# Prediction result: [[0.7393337  0.26066634]], and true label: 52
# Prediction result: [[0.9551276  0.04487232]], and true label: 52
# Prediction result: [[0.0300312  0.96996874]], and true label: 52
# Prediction result: [[0.9334554 0.0665446]], and true label: 52
# Prediction result: [[0.9923475  0.00765252]], and true label: 52
# Prediction result: [[0.97548217 0.02451789]], and true label: 52
# Prediction result: [[0.6514695 0.3485305]], and true label: 52
# Prediction result: [[0.01744623 0.9825538 ]], and true label: 52
# Prediction result: [[0.17813829 0.82186174]], and true label: 52
# Prediction result: [[0.9988997  0.00110032]], and true label: 52
# Prediction result: [[0.9964226  0.00357737]], and true label: 52
# Prediction result: [[0.96072215 0.03927783]], and true label: 52
# Prediction result: [[0.69720143 0.30279854]], and true label: 52
# Prediction result: [[0.96072215 0.03927783]], and true label: 52
# Prediction result: [[9.991665e-01 8.334899e-04]], and true label: 52
# Prediction result: [[0.8894383  0.11056171]], and true label: 52
# Prediction result: [[0.99833137 0.00166868]], and true label: 52
# Prediction result: [[0.23478092 0.76521903]], and true label: 52
# Prediction result: [[0.86721027 0.13278972]], and true label: 52
# Prediction result: [[9.997060e-01 2.940216e-04]], and true label: 52
# Prediction result: [[0.850371   0.14962903]], and true label: 52
# Prediction result: [[0.04198607 0.95801395]], and true label: 52
# Prediction result: [[0.97859573 0.02140423]], and true label: 52
# Prediction result: [[9.9987233e-01 1.2771643e-04]], and true label: 52
# Prediction result: [[9.9985325e-01 1.4675950e-04]], and true label: 52
# Prediction result: [[9.991665e-01 8.334899e-04]], and true label: 52
# Prediction result: [[0.850371   0.14962903]], and true label: 52
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[5.494414e-04 9.994505e-01]], and true label: 99
# Prediction result: [[0.00666605 0.993334  ]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00236043 0.99763954]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.8413107  0.15868926]], and true label: 99
# Prediction result: [[0.989202   0.01079803]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.01744623 0.9825538 ]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.39723408 0.6027659 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00410865 0.99589133]], and true label: 99
# Prediction result: [[0.7257185 0.2742814]], and true label: 99
# Prediction result: [[0.00205474 0.99794525]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[4.0271026e-08 1.0000000e+00]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00410865 0.99589133]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.0300312  0.96996874]], and true label: 99
# Prediction result: [[0.0300312  0.96996874]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.9918012  0.00819878]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00505635 0.9949437 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00410865 0.99589133]], and true label: 99
# Prediction result: [[0.00205474 0.99794525]], and true label: 99
# Prediction result: [[4.1614482e-04 9.9958390e-01]], and true label: 99
# Prediction result: [[0.22252537 0.7774746 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[3.151763e-04 9.996848e-01]], and true label: 99
# Prediction result: [[0.00410865 0.99589133]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.11056171 0.8894383 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.01521663 0.98478335]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[0.00236043 0.99763954]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00765252 0.9923475 ]], and true label: 99
# Prediction result: [[0.00666605 0.993334  ]], and true label: 99
# Prediction result: [[0.63552755 0.36447245]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00878368 0.9912163 ]], and true label: 99
# Prediction result: [[0.05841336 0.9415867 ]], and true label: 99
# Prediction result: [[0.00666605 0.993334  ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00236043 0.99763954]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[2.5826512e-05 9.9997413e-01]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.0280715 0.9719285]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00205474 0.99794525]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[7.2540384e-04 9.9927455e-01]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[4.7817305e-04 9.9952185e-01]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.7116697 0.2883303]], and true label: 99
# Prediction result: [[0.00940992 0.9905901 ]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00940992 0.9905901 ]], and true label: 99
# Prediction result: [[2.7428617e-04 9.9972564e-01]], and true label: 99
# Prediction result: [[0.00205474 0.99794525]], and true label: 99
# Prediction result: [[0.01420949 0.9857905 ]], and true label: 99
# Prediction result: [[0.00236043 0.99763954]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00765252 0.9923475 ]], and true label: 99
# Prediction result: [[0.01420949 0.9857905 ]], and true label: 99
# Prediction result: [[0.02290946 0.9770906 ]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.02623621 0.9737638 ]], and true label: 99
# Prediction result: [[0.00178857 0.9982115 ]], and true label: 99
# Prediction result: [[0.00410865 0.99589133]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.00155682 0.9984432 ]], and true label: 99
# Prediction result: [[0.00765252 0.9923475 ]], and true label: 99
# Prediction result: [[0.08072634 0.91927373]], and true label: 99
# Prediction result: [[0.01999588 0.98000413]], and true label: 99
# Prediction result: [[0.00205474 0.99794525]], and true label: 99
# Prediction result: [[0.02290946 0.9770906 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.7393337  0.26066634]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# Prediction result: [[0.2474966  0.75250334]], and true label: 99
# Prediction result: [[3.6216018e-04 9.9963784e-01]], and true label: 99
# Prediction result: [[0.0665446 0.9334554]], and true label: 99
# Prediction result: [[0.04794704 0.95205295]], and true label: 99
# Prediction result: [[0.00145245 0.9985475 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[0.00271148 0.9972886 ]], and true label: 99
# Prediction result: [[0.00357737 0.9964226 ]], and true label: 99
# Prediction result: [[0.00311457 0.99688536]], and true label: 99
# Prediction result: [[1.5732042e-04 9.9984264e-01]], and true label: 99
# Prediction result: [[0.005806 0.994194]], and true label: 99
# Prediction result: [[0.00236043 0.99763954]], and true label: 99
# Prediction result: [[0.00135506 0.9986449 ]], and true label: 99
# total sounds result is 85.65573770491804
# total alarm sounds result is 75.86206896551724
# total other sounds result is 94.53125

# %%
# scores = model.predict(sound, batch_size=len(sound), verbose=0);
# print(type(scores))
# print(scores.shape)

# for res in scores:
#     max_value = res.max()
#     max_index = np.argmax(res)
#     print(f"max value:{max_value:.5f} and index is {max_index}")
#     print('\n'.join('{}: {:.5f}'.format(*k) for k in enumerate(res)))
