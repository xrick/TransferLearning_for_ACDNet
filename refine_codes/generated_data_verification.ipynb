# %%
import sys
import os
import numpy as np

# %%
# original_training_data_path = "../../acdnet_training_data/original_paper_training_data/wav20.npz"
original_training_data_path = "../../../../CodeRepo/SED_Repo/ACDNet/acdnet-master/common/datasets/esc50/wav20.npz"
mytraining_data_path = "../datasets/forOneClassModel_alarm/train/trainSet_20240119002902.npz"
mytest_data_path = "../datasets/forOneClassModel_alarm/test_val/final_val_test_npz/final_valSet_20240119004614.npz"

# %%
# dataset20 = np.load(original_training_data_path, allow_pickle=True)
# datasetmy = np.load(mytraining_data_path, allow_pickle=True)
valdata = np.load(mytest_data_path,allow_pickle=True)

# %%
print(valdata['x'].shape)
# Out:
# (176, 1, 30225, 1)

# %%
print(type(dataset20))
# Out:
# <class 'numpy.lib.npyio.NpzFile'>

# %%
# print(dataset20['fold1'])
sounds = dataset20['fold1'].item()['sounds']
print(type(sounds))
# Out:
# <class 'list'>

# %%
print(datasetmy['fold1'])
# Out:
# {'sounds': [array([-100, -177, -185, ...,  243,  635,   37], dtype=int16), array([  -67,  -120,   -82, ...,  1752, -1175, -3221], dtype=int16), array([  -736,  -1207,  -1694, ..., -10999,  -6689,  -3064], dtype=int16), array([10533, 11644, -2938, ...,  6297, 15844, 18310], dtype=int16), array([  -70,   -24,   134, ..., -2939,  -995,  2321], dtype=int16), array([ -6857, -13097,  -4130, ...,    399,    474,    404], dtype=int16), array([   48,   196,   170, ..., -6508, 31398, 32767], dtype=int16), array([ -113,  -200,  -140, ...,  1634, -2298, -4020], dtype=int16), array([   229,    153,    113, ...,  31458,  30477, -23027], dtype=int16), array([3837, 5341, 1757, ..., -105, -124,  -49], dtype=int16), array([  9361,  12672,  -7303, ..., -31465,  -2619,  28074], dtype=int16), array([ -254,   272,  1356, ..., -1424,   959,  2113], dtype=int16), array([3526, 3427, 1619, ..., 4722, 5040, 3479], dtype=int16), array([   213,    167,     51, ..., -32766, -32768, -32765], dtype=int16), array([ 
# ...

# %%
soundsmy = datasetmy['fold1'].item()['sounds']
print(len(soundsmy))
# Out:
# 325
